# %%
from keras.datasets import mnist
from keras.utils import np_utils
import keras.layers as layers
import tensorflow as tf
from tensorflow import keras
from keras.models import Model

(X_train, y_train), (X_test, y_test) = mnist.load_data()
print('X_train shape:', X_train.shape)
print(X_train.shape[0], 'train samples')
print(X_test.shape[0] , 'test samples')
# Out:
# Using TensorFlow backend.
# Downloading data from https://s3.amazonaws.com/img-datasets/mnist.npz
# 11493376/11490434 [==============================] - 2s 0us/step
# X_train shape: (60000, 28, 28)
# 60000 train samples
# 10000 test samples

# %%
# !pip install -q keras

# %%
# !pip install -q tensorflow

# %%
n_classes = 10
img_rows, img_cols = 28, 28

# mnist is grey-scaled image, thus the last dimension, channel size will be 1
X_train = X_train.reshape(X_train.shape[0], img_rows, img_cols, 1)
X_test = X_test.reshape(X_test.shape[0], img_rows, img_cols, 1)
input_shape = img_rows, img_cols, 1

X_train = X_train.astype('float32')
X_test  = X_test.astype('float32')

# images takes values between 0 - 255, we can normalize it
# by dividing every number by 255
X_train /= 255
X_test /= 255
print('train shape:', X_train.shape)

# one-hot encode the class (target) vectors
Y_train = np_utils.to_categorical(y_train, n_classes)
Y_test = np_utils.to_categorical(y_test , n_classes)
print('y_train shape:', Y_train.shape)
# Out:
# train shape: (60000, 28, 28, 1)
# y_train shape: (60000, 10)

# %%
def conv_block(input_tensor, kernel_size, filters, stage, block, strides=(2, 2)):
    """ 
    A block that has a conv layer at shortcut.

    Parameters
    ----------
    input_tensor:
    
    kernel_size: int
        The kernel size of middle conv layer at main path.

    filters: list[int]
        The filters of 3 conv layer at main path.

    stage: int
        Current stage label, used for generating layer names.

    block: : str
        'a','b'..., current block label, used for generating layer names.
        
    strides : tuple, default (2, 2)
        Strides for the first conv layer in the block.

    Returns
    -------
    Output tensor for the block.
    """
    conv_name_base = 'res' + str(stage) + block + '_branch'
    bn_name_base = 'bn' + str(stage) + block + '_branch'
    
    # for batch normalization layer, we assume
    # the input data is in channel last format,
    # which is the case if we are using the default
    # keras' backend tensorflow
    bn_axis = 3

    filters1, filters2, filters3 = filters
  
    # main path, note that setting the kernel_initializer set here is only used
    # for reproducibility, we techniqually don't need it
    x = layers.Conv2D(filters1, kernel_size=(1, 1), strides=strides,
                      kernel_initializer=glorot_uniform(seed=0),
                      padding='valid', name=conv_name_base + '2a')(input_tensor)
    x = layers.BatchNormalization(axis=bn_axis, name=bn_name_base + '2a')(x)
    x = layers.Activation('relu')(x)

    x = layers.Conv2D(filters2, kernel_size, strides=(1, 1),
                      kernel_initializer=glorot_uniform(seed=0),
                      padding='same', name=conv_name_base + '2b')(x)
    x = layers.BatchNormalization(axis=bn_axis, name=bn_name_base + '2b')(x)
    x = layers.Activation('relu')(x)

    x = layers.Conv2D(filters3, kernel_size=(1, 1), strides=(1, 1),
                      kernel_initializer=glorot_uniform(seed=0),
                      padding='valid', name=conv_name_base + '2c')(x)
    x = layers.BatchNormalization(axis=bn_axis, name=bn_name_base + '2c')(x)
    
    # we resize the input so its dimension will match the output dimension
    # of the main path
    shortcut = layers.Conv2D(filters3, kernel_size=(1, 1), strides=strides,
                             kernel_initializer=glorot_uniform(seed=0),
                             padding='valid', name=conv_name_base + '1')(input_tensor)
    shortcut = layers.BatchNormalization(axis=bn_axis, name=bn_name_base + '1')(shortcut) 

    # this line is the core component of resnet, the skip connection, i.e.
    # having a shortcut to the main path before the activation
    x = layers.add([x, shortcut])
    x = layers.Activation('relu')(x)
    return x

# %%
from keras.initializers import glorot_uniform


def identity_block(input_tensor, kernel_size, filters, stage, block):
    """ 
    An identity block.

    Parameters
    ----------
    input_tensor:

    kernel_size: int
        The kernel size of middle conv layer at main path.

    filters: list[int]
        The filters of 3 conv layer at main path.

    stage: int
        Current stage label, used for generating layer names.

    block: : str
        'a','b'..., current block label, used for generating layer names.

    Returns
    -------
    Output tensor for the block.
    """
    conv_name_base = 'res' + str(stage) + block + '_branch'
    bn_name_base = 'bn' + str(stage) + block + '_branch'
    
    # for batch normalization layer, we assume
    # the input data is in channel last format
    bn_axis = 3

    filters1, filters2, filters3 = filters
  
    # main path, note that setting the kernel_initializer seed here is only used
    # for reproducibility, we techniqually don't need it
    x = layers.Conv2D(filters1, kernel_size=(1, 1), strides=(1, 1),
                      kernel_initializer=glorot_uniform(seed=0),
                      padding='valid', name=conv_name_base + '2a')(input_tensor)
    x = layers.BatchNormalization(axis=bn_axis, name=bn_name_base + '2a')(x)
    x = layers.Activation('relu')(x)

    x = layers.Conv2D(filters2, kernel_size, strides=(1, 1),
                      kernel_initializer=glorot_uniform(seed=0),
                      padding='same', name=conv_name_base + '2b')(x)
    x = layers.BatchNormalization(axis=bn_axis, name=bn_name_base + '2b')(x)
    x = layers.Activation('relu')(x)

    x = layers.Conv2D(filters3, kernel_size=(1, 1), strides=(1, 1),
                      kernel_initializer=glorot_uniform(seed=0),
                      padding='valid', name=conv_name_base + '2c')(x)
    x = layers.BatchNormalization(axis=bn_axis, name=bn_name_base + '2c')(x)

    # this line is the core component of resnet, the skip connection, i.e.
    # having a shortcut to the main path before the activation, when addition
    # is performed on convolutional layers, the element-wise addition is performed
    # on their feature maps, i.e. channel by channel
    x = layers.add([x, input_tensor])
    x = layers.Activation('relu')(x)
    return x

# %%
def ResNet(input_shape, n_classes):
    """
    Definition of ResNet
    
    References
    ----------
    https://github.com/keras-team/keras-applications/blob/master/keras_applications/resnet50.py
    """
    img_input = layers.Input(shape=input_shape)
    
    bn_axis = 3
    
    x = layers.ZeroPadding2D(padding=(3, 3), name='conv1_pad')(img_input)
    x = layers.Conv2D(64, (7, 7),
                      strides=(2, 2),
                      padding='valid',
                      kernel_initializer='he_normal',
                      name='conv1')(x)
    x = layers.BatchNormalization(axis=bn_axis, name='bn_conv1')(x)
    x = layers.Activation('relu')(x)
    x = layers.ZeroPadding2D(padding=(1, 1), name='pool1_pad')(x)
    x = layers.MaxPooling2D((3, 3), strides=(2, 2))(x)

    x = conv_block(x, 3, [64, 64, 256], stage=2, block='a', strides=(1, 1))
    x = identity_block(x, 3, [64, 64, 256], stage=2, block='b')
    x = identity_block(x, 3, [64, 64, 256], stage=2, block='c')

    x = conv_block(x, 3, [128, 128, 512], stage=3, block='a')
    x = identity_block(x, 3, [128, 128, 512], stage=3, block='b')
    x = identity_block(x, 3, [128, 128, 512], stage=3, block='c')
    x = identity_block(x, 3, [128, 128, 512], stage=3, block='d')
    
    # the commented out blocks are what's needed to build out the
    # full ResNet50 (a ResNet with 50 layers), we won't be needing
    # the complexity here
    # x = conv_block(x, 3, [256, 256, 1024], stage=4, block='a')
    # x = identity_block(x, 3, [256, 256, 1024], stage=4, block='b')
    # x = identity_block(x, 3, [256, 256, 1024], stage=4, block='c')
    # x = identity_block(x, 3, [256, 256, 1024], stage=4, block='d')
    # x = identity_block(x, 3, [256, 256, 1024], stage=4, block='e')
    # x = identity_block(x, 3, [256, 256, 1024], stage=4, block='f')

    # x = conv_block(x, 3, [512, 512, 2048], stage=5, block='a')
    # x = identity_block(x, 3, [512, 512, 2048], stage=5, block='b')
    # x = identity_block(x, 3, [512, 512, 2048], stage=5, block='c')
    
    x = layers.GlobalAveragePooling2D(name='avg_pool')(x)
    img_output = layers.Dense(n_classes, activation='softmax', name='fc' + str(n_classes))(x)

    model = Model(inputs=img_input, outputs=img_output, name='resnet')
    return model


model = ResNet(input_shape, n_classes)
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# Model: "resnet"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 28, 28, 1)    0
# __________________________________________________________________________________________________
# conv1_pad (ZeroPadding2D)       (None, 34, 34, 1)    0           input_1[0][0]
# __________________________________________________________________________________________________
# conv1 (Conv2D)                  (None, 14, 14, 64)   3200        conv1_pad[0][0]
# __________________________________________________________________________________________________
# bn_conv1 (BatchNormalization)   (None, 14, 14, 64)   256         conv1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 14, 14, 64)   0           bn_conv1[0][0]
# __________________________________________________________________________________________________
# pool1_pad (ZeroPadding2D)       (None, 16, 16, 64)   0           activation_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 7, 7, 64)     0           pool1_pad[0][0]
# __________________________________________________________________________________________________
# res2a_branch2a (Conv2D)         (None, 7, 7, 64)     4160        max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2a (BatchNormalizati (None, 7, 7, 64)     256         res2a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 7, 7, 64)     0           bn2a_branch2a[0][0]
# __________________________________________________________________________________________________
# res2a_branch2b (Conv2D)         (None, 7, 7, 64)     36928       activation_2[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2b (BatchNormalizati (None, 7, 7, 64)     256         res2a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 7, 7, 64)     0           bn2a_branch2b[0][0]
# __________________________________________________________________________________________________
# res2a_branch2c (Conv2D)         (None, 7, 7, 256)    16640       activation_3[0][0]
# __________________________________________________________________________________________________
# res2a_branch1 (Conv2D)          (None, 7, 7, 256)    16640       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2c (BatchNormalizati (None, 7, 7, 256)    1024        res2a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn2a_branch1 (BatchNormalizatio (None, 7, 7, 256)    1024        res2a_branch1[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 7, 7, 256)    0           bn2a_branch2c[0][0]
#                                                                  bn2a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 7, 7, 256)    0           add_1[0][0]
# __________________________________________________________________________________________________
# res2b_branch2a (Conv2D)         (None, 7, 7, 64)     16448       activation_4[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2a (BatchNormalizati (None, 7, 7, 64)     256         res2b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 7, 7, 64)     0           bn2b_branch2a[0][0]
# __________________________________________________________________________________________________
# res2b_branch2b (Conv2D)         (None, 7, 7, 64)     36928       activation_5[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2b (BatchNormalizati (None, 7, 7, 64)     256         res2b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 7, 7, 64)     0           bn2b_branch2b[0][0]
# __________________________________________________________________________________________________
# res2b_branch2c (Conv2D)         (None, 7, 7, 256)    16640       activation_6[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2c (BatchNormalizati (None, 7, 7, 256)    1024        res2b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 7, 7, 256)    0           bn2b_branch2c[0][0]
#                                                                  activation_4[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 7, 7, 256)    0           add_2[0][0]
# __________________________________________________________________________________________________
# res2c_branch2a (Conv2D)         (None, 7, 7, 64)     16448       activation_7[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2a (BatchNormalizati (None, 7, 7, 64)     256         res2c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 7, 7, 64)     0           bn2c_branch2a[0][0]
# __________________________________________________________________________________________________
# res2c_branch2b (Conv2D)         (None, 7, 7, 64)     36928       activation_8[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2b (BatchNormalizati (None, 7, 7, 64)     256         res2c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 7, 7, 64)     0           bn2c_branch2b[0][0]
# __________________________________________________________________________________________________
# res2c_branch2c (Conv2D)         (None, 7, 7, 256)    16640       activation_9[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2c (BatchNormalizati (None, 7, 7, 256)    1024        res2c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 7, 7, 256)    0           bn2c_branch2c[0][0]
#                                                                  activation_7[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 7, 7, 256)    0           add_3[0][0]
# __________________________________________________________________________________________________
# res3a_branch2a (Conv2D)         (None, 4, 4, 128)    32896       activation_10[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2a (BatchNormalizati (None, 4, 4, 128)    512         res3a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 4, 4, 128)    0           bn3a_branch2a[0][0]
# __________________________________________________________________________________________________
# res3a_branch2b (Conv2D)         (None, 4, 4, 128)    147584      activation_11[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2b (BatchNormalizati (None, 4, 4, 128)    512         res3a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 4, 4, 128)    0           bn3a_branch2b[0][0]
# __________________________________________________________________________________________________
# res3a_branch2c (Conv2D)         (None, 4, 4, 512)    66048       activation_12[0][0]
# __________________________________________________________________________________________________
# res3a_branch1 (Conv2D)          (None, 4, 4, 512)    131584      activation_10[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2c (BatchNormalizati (None, 4, 4, 512)    2048        res3a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn3a_branch1 (BatchNormalizatio (None, 4, 4, 512)    2048        res3a_branch1[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 4, 4, 512)    0           bn3a_branch2c[0][0]
#                                                                  bn3a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 4, 4, 512)    0           add_4[0][0]
# __________________________________________________________________________________________________
# res3b_branch2a (Conv2D)         (None, 4, 4, 128)    65664       activation_13[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2a (BatchNormalizati (None, 4, 4, 128)    512         res3b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 4, 4, 128)    0           bn3b_branch2a[0][0]
# __________________________________________________________________________________________________
# res3b_branch2b (Conv2D)         (None, 4, 4, 128)    147584      activation_14[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2b (BatchNormalizati (None, 4, 4, 128)    512         res3b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 4, 4, 128)    0           bn3b_branch2b[0][0]
# __________________________________________________________________________________________________
# res3b_branch2c (Conv2D)         (None, 4, 4, 512)    66048       activation_15[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2c (BatchNormalizati (None, 4, 4, 512)    2048        res3b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 4, 4, 512)    0           bn3b_branch2c[0][0]
#                                                                  activation_13[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 4, 4, 512)    0           add_5[0][0]
# __________________________________________________________________________________________________
# res3c_branch2a (Conv2D)         (None, 4, 4, 128)    65664       activation_16[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2a (BatchNormalizati (None, 4, 4, 128)    512         res3c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 4, 4, 128)    0           bn3c_branch2a[0][0]
# __________________________________________________________________________________________________
# res3c_branch2b (Conv2D)         (None, 4, 4, 128)    147584      activation_17[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2b (BatchNormalizati (None, 4, 4, 128)    512         res3c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 4, 4, 128)    0           bn3c_branch2b[0][0]
# __________________________________________________________________________________________________
# res3c_branch2c (Conv2D)         (None, 4, 4, 512)    66048       activation_18[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2c (BatchNormalizati (None, 4, 4, 512)    2048        res3c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 4, 4, 512)    0           bn3c_branch2c[0][0]
#                                                                  activation_16[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 4, 4, 512)    0           add_6[0][0]
# __________________________________________________________________________________________________
# res3d_branch2a (Conv2D)         (None, 4, 4, 128)    65664       activation_19[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2a (BatchNormalizati (None, 4, 4, 128)    512         res3d_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 4, 4, 128)    0           bn3d_branch2a[0][0]
# __________________________________________________________________________________________________
# res3d_branch2b (Conv2D)         (None, 4, 4, 128)    147584      activation_20[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2b (BatchNormalizati (None, 4, 4, 128)    512         res3d_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 4, 4, 128)    0           bn3d_branch2b[0][0]
# __________________________________________________________________________________________________
# res3d_branch2c (Conv2D)         (None, 4, 4, 512)    66048       activation_21[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2c (BatchNormalizati (None, 4, 4, 512)    2048        res3d_branch2c[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 4, 4, 512)    0           bn3d_branch2c[0][0]
#                                                                  activation_19[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 4, 4, 512)    0           add_7[0][0]
# __________________________________________________________________________________________________
# avg_pool (GlobalAveragePooling2 (None, 512)          0           activation_22[0][0]
# __________________________________________________________________________________________________
# fc10 (Dense)                    (None, 10)           5130        avg_pool[0][0]
# ==================================================================================================
# Total params: 1,458,954
# Trainable params: 1,448,842
# Non-trainable params: 10,112
# __________________________________________________________________________________________________

# %%
history = model.fit(X_train, Y_train, epochs=30, batch_size=32)
# Out:
# Epoch 1/30
# 60000/60000 [==============================] - 77s 1ms/step - loss: 0.1453 - accuracy: 0.9560
# Epoch 2/30
# 60000/60000 [==============================] - 67s 1ms/step - loss: 0.0643 - accuracy: 0.9813
# Epoch 3/30
# 60000/60000 [==============================] - 65s 1ms/step - loss: 0.0486 - accuracy: 0.9857
# Epoch 4/30
# 60000/60000 [==============================] - 66s 1ms/step - loss: 0.0382 - accuracy: 0.9889
# Epoch 5/30
# 60000/60000 [==============================] - 65s 1ms/step - loss: 0.0339 - accuracy: 0.9894
# Epoch 6/30
# 60000/60000 [==============================] - 67s 1ms/step - loss: 0.0260 - accuracy: 0.9916
# Epoch 7/30
# 60000/60000 [==============================] - 65s 1ms/step - loss: 0.0217 - accuracy: 0.9933
# Epoch 8/30
# 60000/60000 [==============================] - 64s 1ms/step - loss: 0.0191 - accuracy: 0.9943
# Epoch 9/30
# 60000/60000 [==============================] - 64s 1ms/step - loss: 0.0158 - accuracy: 0.9951
# Epoch 10/30
# 60000/60000 [==============================] - 64s 1ms/step - loss: 0.0147 - accuracy: 0.9953
# Epoch 11/30
# 60000/60000 [==============================] - 65s 1ms/step - loss: 0.0140 - accuracy: 0.9955
# Epoch 12/30
# 60000/60000 [==============================] - 64s 1ms/step - loss: 0.0107 - accuracy: 0.9963
# Epoch 13/30
# 60000/60000 [==============================] - 64s 1ms/step - loss: 0.0090 - accuracy: 0.9972
# Epoch 14/30
# 60000/60000 [==============================] - 64s 1ms/step - loss: 0.0105 - accuracy: 0.9966
# Epoch 15/30
# 60000/60000 [==============================] - 64s 1ms/step - loss: 0.0078 - accuracy: 0.9974
# Epoch 16/30
# 60000/60000 [==============================] - 64s 1ms/step - loss: 0.0087 - accuracy: 0.9973
# Epoch 17/30
# 60000/60000 [==============================] - 64s 1ms/step - loss: 0.0066 - accuracy: 0.9980
# Epoch 18/30
# 60000/60000 [==============================] - 64s 1ms/step - loss: 0.0063 - accuracy: 0.9980
# Epoch 19/30
# 60000/60000 [==============================] - 64s 1ms/step - loss: 0.0094 - accuracy: 0.9975
# Epoch 20/30
# 60000/60000 [==============================] - 64s 1ms/step - loss: 0.0051 - accuracy: 0.9984
# Epoch 21/30
# 60000/60000 [==============================] - 64s 1ms/step - loss: 0.0056 - accuracy: 0.9983
# Epoch 22/30
# 60000/60000 [==============================] - 64s 1ms/step - loss: 0.0062 - accuracy: 0.9981
# Epoch 23/30
# 60000/60000 [==============================] - 64s 1ms/step - loss: 0.0054 - accuracy: 0.9984
# Epoch 24/30
# 60000/60000 [==============================] - 64s 1ms/step - loss: 0.0048 - accuracy: 0.9984
# Epoch 25/30
# 60000/60000 [==============================] - 64s 1ms/step - loss: 0.0041 - accuracy: 0.9987
# Epoch 26/30
# 60000/60000 [==============================] - 65s 1ms/step - loss: 0.0043 - accuracy: 0.9985
# Epoch 27/30
# 60000/60000 [==============================] - 65s 1ms/step - loss: 0.0033 - accuracy: 0.9991
# Epoch 28/30
# 60000/60000 [==============================] - 65s 1ms/step - loss: 0.0043 - accuracy: 0.9988
# Epoch 29/30
# 60000/60000 [==============================] - 65s 1ms/step - loss: 0.0041 - accuracy: 0.9987
# Epoch 30/30
# 60000/60000 [==============================] - 65s 1ms/step - loss: 0.0038 - accuracy: 0.9989

# %%
loss, accuracy = model.evaluate(X_test, Y_test)
print('Loss = ' + str(loss))
print('Test Accuracy = ' + str(accuracy))
# Out:
# 10000/10000 [==============================] - 3s 322us/step
# Loss = 0.024799418166302323
# Test Accuracy = 0.9937999844551086
