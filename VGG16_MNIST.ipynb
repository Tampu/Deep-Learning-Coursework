# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive/

# %%
# !ls "/content/drive/My Drive/"
# Out:
# 'Data Analytics'  'Deep Learning'  'Getting started.pdf'

# %%
# !pip install -q keras

# %%
# !pip install ipython
# Out:
# Requirement already satisfied: ipython in /usr/local/lib/python3.6/dist-packages (5.5.0)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.6/dist-packages (from ipython) (0.7.5)
# Requirement already satisfied: simplegeneric>0.8 in /usr/local/lib/python3.6/dist-packages (from ipython) (0.8.1)
# Requirement already satisfied: pexpect; sys_platform != "win32" in /usr/local/lib/python3.6/dist-packages (from ipython) (4.8.0)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.6/dist-packages (from ipython) (46.1.3)
# Requirement already satisfied: decorator in /usr/local/lib/python3.6/dist-packages (from ipython) (4.4.2)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.6/dist-packages (from ipython) (4.3.3)
# Requirement already satisfied: pygments in /usr/local/lib/python3.6/dist-packages (from ipython) (2.1.3)
# Requirement already satisfied: prompt-toolkit<2.0.0,>=1.0.4 in /usr/local/lib/python3.6/dist-packages (from ipython) (1.0.18)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.6/dist-packages (from pexpect; sys_platform != "win32"->ipython) (0.6.0)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from traitlets>=4.2->ipython) (1.12.0)
# Requirement already satisfied: ipython-genutils in /usr/local/lib/python3.6/dist-packages (from traitlets>=4.2->ipython) (0.2.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.6/dist-packages (from prompt-toolkit<2.0.0,>=1.0.4->ipython) (0.1.9)

# %%
import os
import numpy as np
from keras.datasets import mnist
from keras.utils.np_utils import to_categorical
import matplotlib.pyplot as plt

from keras.models import Sequential
from keras.layers import Input, Dropout, Flatten, Conv2D, MaxPooling2D, Dense, Activation, Reshape
from keras.optimizers import RMSprop
from keras.callbacks import ModelCheckpoint, Callback, EarlyStopping
from keras.utils import np_utils
# Out:
# Using TensorFlow backend.

# %%
(x_train, y_train), (x_test, y_test) = mnist.load_data()
print('x_train shape:', x_train.shape)
print("Train Set Size = {} images".format(y_train.shape[0]))
print("Test Set Size = {} images".format(y_test.shape[0]))
# Out:
# Downloading data from https://s3.amazonaws.com/img-datasets/mnist.npz
# 11493376/11490434 [==============================] - 1s 0us/step
# x_train shape: (60000, 28, 28)
# Train Set Size = 60000 images
# Test Set Size = 10000 images

# %%
fig1 = plt.figure(figsize = (15,15))

for i in range(5):
    ax1 = fig1.add_subplot(1,5,i+1) 
    ax1.imshow(x_train[i], interpolation='none', cmap=plt.cm.gray)
    ax2 = fig1.add_subplot(2,5,i+6) 
    ax2.imshow(x_train[i+6], interpolation='none', cmap=plt.cm.gray)
plt.show()

print("Labels : {}".format(y_train[0:5]))
print("Labels : {}".format(y_train[6:11]))
# Out:
# Labels : [5 0 4 1 9]
# Labels : [1 3 1 4 3]

# %%
y_train_onehot = to_categorical(y_train, num_classes=None, dtype='float32')

# %%
optimizer = RMSprop(lr=1e-4)
objective = 'binary_crossentropy'

def vgg16():
    model = Sequential()
    model.add(Reshape((28, 28, 1)))
    model.add(Conv2D(64, (3, 3), padding='same', input_shape=((28, 28, 1)), activation='relu'))
    model.add(Conv2D(64, (3, 3), padding='same', activation='relu'))
    model.add(MaxPooling2D(data_format="channels_last", pool_size=(2, 2)))

    model.add(Conv2D(128, (3, 3), padding='same', activation='relu'))
    model.add(Conv2D(128, (3, 3), padding='same', activation='relu'))
    model.add(MaxPooling2D(data_format="channels_last", pool_size=(2, 2)))
    
    model.add(Conv2D(256, (3, 3), padding='same', activation='relu'))
    model.add(Conv2D(256, (3, 3), padding='same', activation='relu'))
    model.add(Conv2D(256, (3, 3), padding='same', activation='relu'))
    model.add(MaxPooling2D(data_format="channels_last", pool_size=(2, 2)))
    
    model.add(Conv2D(512, (3, 3), padding='same', activation='relu'))
    model.add(Conv2D(512, (3, 3), padding='same', activation='relu'))
    model.add(Conv2D(512, (3, 3), padding='same', activation='relu'))
    model.add(MaxPooling2D(data_format="channels_last", pool_size=(2, 2)))

    model.add(Conv2D(512, (3, 3), padding='same', activation='relu'))
    model.add(Conv2D(512, (3, 3), padding='same', activation='relu'))
    model.add(Conv2D(512, (3, 3), padding='same', activation='relu'))
    #model.add(MaxPooling2D(data_format="channels_last", pool_size=(2, 2)))

    model.add(Flatten())
    model.add(Dense(256, activation='relu'))
    model.add(Dropout(0.5))
    
    model.add(Dense(256, activation='relu'))
    model.add(Dropout(0.5))

    model.add(Dense(10))
    model.add(Activation('softmax'))

    model.compile(loss=objective, optimizer=optimizer, metrics=['accuracy'])
    return model


model = vgg16()

# %%
nb_epoch = 50
batch_size = 128

## Callback for loss logging per epoch
class LossHistory(Callback):
    def on_train_begin(self, logs={}):
        self.losses = []
        self.val_losses = []
        self.acc = []
        self.val_acc = []
        
    def on_epoch_end(self, batch, logs={}):
        self.losses.append(logs.get('loss'))
        self.val_losses.append(logs.get('val_loss'))
        self.acc.append(logs.get('accuracy'))
        self.val_acc.append(logs.get('val_accuracy'))

early_stopping = EarlyStopping(monitor='val_loss', patience=100, verbose=1, mode='auto')

def run_vgg16():
    
    history = LossHistory()
    model.fit(x_train, y_train_onehot, batch_size=batch_size, epochs=nb_epoch,
              validation_split=0.25, verbose=1, shuffle=True, callbacks=[history, early_stopping])
    

    predictions = model.predict(x_test, verbose=0)
    return predictions, history

def test_accuracy():
    err = []
    t = 0
    for i in range(predictions.shape[0]):
        if (np.argmax(predictions[i]) == y_test[i]):
            t = t+1
        else:
            err.append(i)
    return t, float(t)*100/predictions.shape[0], err

# %%
# %%time
predictions, history = run_vgg16()
print(model.summary())
# Out:
# Train on 45000 samples, validate on 15000 samples
# Epoch 1/50
# 45000/45000 [==============================] - 13s 293us/step - loss: 0.0216 - accuracy: 0.9943 - val_loss: 0.0207 - val_accuracy: 0.9945
# Epoch 2/50
# 45000/45000 [==============================] - 13s 292us/step - loss: 0.0130 - accuracy: 0.9967 - val_loss: 0.0100 - val_accuracy: 0.9974
# Epoch 3/50
# 45000/45000 [==============================] - 13s 292us/step - loss: 0.0092 - accuracy: 0.9976 - val_loss: 0.0130 - val_accuracy: 0.9972
# Epoch 4/50
# 45000/45000 [==============================] - 13s 292us/step - loss: 0.0072 - accuracy: 0.9982 - val_loss: 0.0094 - val_accuracy: 0.9977
# Epoch 5/50
# 45000/45000 [==============================] - 13s 292us/step - loss: 0.0059 - accuracy: 0.9986 - val_loss: 0.0108 - val_accuracy: 0.9978
# Epoch 6/50
# 45000/45000 [==============================] - 13s 292us/step - loss: 0.0055 - accuracy: 0.9986 - val_loss: 0.0136 - val_accuracy: 0.9975
# Epoch 7/50
# 45000/45000 [==============================] - 13s 291us/step - loss: 0.0044 - accuracy: 0.9989 - val_loss: 0.0115 - val_accuracy: 0.9978
# Epoch 8/50
# 45000/45000 [==============================] - 13s 292us/step - loss: 0.0043 - accuracy: 0.9991 - val_loss: 0.0131 - val_accuracy: 0.9982
# Epoch 9/50
# 45000/45000 [==============================] - 13s 291us/step - loss: 0.0039 - accuracy: 0.9991 - val_loss: 0.0166 - val_accuracy: 0.9976
# Epoch 10/50
# 45000/45000 [==============================] - 13s 290us/step - loss: 0.0035 - accuracy: 0.9992 - val_loss: 0.0101 - val_accuracy: 0.9983
# Epoch 11/50
# 45000/45000 [==============================] - 13s 290us/step - loss: 0.0035 - accuracy: 0.9993 - val_loss: 0.0118 - val_accuracy: 0.9983
# Epoch 12/50
# 45000/45000 [==============================] - 13s 296us/step - loss: 0.0036 - accuracy: 0.9993 - val_loss: 0.0137 - val_accuracy: 0.9979
# Epoch 13/50
# 45000/45000 [==============================] - 13s 296us/step - loss: 0.0033 - accuracy: 0.9993 - val_loss: 0.0177 - val_accuracy: 0.9979
# Epoch 14/50
# 45000/45000 [==============================] - 13s 293us/step - loss: 0.0031 - accuracy: 0.9994 - val_loss: 0.0126 - val_accuracy: 0.9976
# Epoch 15/50
# 45000/45000 [==============================] - 13s 295us/step - loss: 0.0032 - accuracy: 0.9994 - val_loss: 0.0170 - val_accuracy: 0.9978
# Epoch 16/50
# 45000/45000 [==============================] - 13s 297us/step - loss: 0.0032 - accuracy: 0.9994 - val_loss: 0.0160 - val_accuracy: 0.9980
# Epoch 17/50
# 45000/45000 [==============================] - 13s 294us/step - loss: 0.0029 - accuracy: 0.9995 - val_loss: 0.0096 - val_accuracy: 0.9981
# Epoch 18/50
# 45000/45000 [==============================] - 13s 295us/step - loss: 0.0041 - accuracy: 0.9994 - val_loss: 0.0153 - val_accuracy: 0.9963
# Epoch 19/50
# 45000/45000 [==============================] - 13s 294us/step - loss: 0.0033 - accuracy: 0.9995 - val_loss: 0.0127 - val_accuracy: 0.9979
# Epoch 20/50
# 45000/45000 [==============================] - 13s 293us/step - loss: 0.0033 - accuracy: 0.9995 - val_loss: 0.0134 - val_accuracy: 0.9985
# Epoch 21/50
# 45000/45000 [==============================] - 13s 296us/step - loss: 0.0041 - accuracy: 0.9994 - val_loss: 0.0323 - val_accuracy: 0.9974
# Epoch 22/50
# 45000/45000 [==============================] - 13s 295us/step - loss: 0.0068 - accuracy: 0.9992 - val_loss: 0.0099 - val_accuracy: 0.9983
# Epoch 23/50
# 45000/45000 [==============================] - 13s 295us/step - loss: 0.0038 - accuracy: 0.9994 - val_loss: 0.0176 - val_accuracy: 0.9982
# Epoch 24/50
# 45000/45000 [==============================] - 13s 295us/step - loss: 0.0045 - accuracy: 0.9994 - val_loss: 0.0320 - val_accuracy: 0.9973
# Epoch 25/50
# 45000/45000 [==============================] - 13s 294us/step - loss: 0.0040 - accuracy: 0.9994 - val_loss: 0.0159 - val_accuracy: 0.9985
# Epoch 26/50
# 45000/45000 [==============================] - 13s 295us/step - loss: 0.0036 - accuracy: 0.9995 - val_loss: 0.0306 - val_accuracy: 0.9978
# Epoch 27/50
# 45000/45000 [==============================] - 13s 296us/step - loss: 0.0107 - accuracy: 0.9988 - val_loss: 0.0184 - val_accuracy: 0.9966
# Epoch 28/50
# 45000/45000 [==============================] - 13s 294us/step - loss: 0.0041 - accuracy: 0.9993 - val_loss: 0.0195 - val_accuracy: 0.9983
# Epoch 29/50
# 45000/45000 [==============================] - 13s 294us/step - loss: 0.0072 - accuracy: 0.9991 - val_loss: 0.0229 - val_accuracy: 0.9983
# Epoch 30/50
# 45000/45000 [==============================] - 13s 295us/step - loss: 0.0068 - accuracy: 0.9993 - val_loss: 0.0371 - val_accuracy: 0.9973
# Epoch 31/50
# 45000/45000 [==============================] - 13s 295us/step - loss: 0.0136 - accuracy: 0.9988 - val_loss: 0.0209 - val_accuracy: 0.9935
# Epoch 32/50
# 45000/45000 [==============================] - 13s 295us/step - loss: 0.0057 - accuracy: 0.9993 - val_loss: 0.0417 - val_accuracy: 0.9971
# Epoch 33/50
# 45000/45000 [==============================] - 13s 295us/step - loss: 0.0057 - accuracy: 0.9993 - val_loss: 0.0231 - val_accuracy: 0.9983
# Epoch 34/50
# 45000/45000 [==============================] - 13s 296us/step - loss: 0.0087 - accuracy: 0.9992 - val_loss: 0.0347 - val_accuracy: 0.9973
# Epoch 35/50
# 45000/45000 [==============================] - 13s 295us/step - loss: 0.0080 - accuracy: 0.9991 - val_loss: 0.0211 - val_accuracy: 0.9981
# Epoch 36/50
# 45000/45000 [==============================] - 13s 295us/step - loss: 0.0072 - accuracy: 0.9993 - val_loss: 0.0261 - val_accuracy: 0.9973
# Epoch 37/50
# 45000/45000 [==============================] - 13s 295us/step - loss: 0.0072 - accuracy: 0.9991 - val_loss: 0.0157 - val_accuracy: 0.9979
# Epoch 38/50
# 45000/45000 [==============================] - 13s 295us/step - loss: 0.0071 - accuracy: 0.9993 - val_loss: 0.0175 - val_accuracy: 0.9976
# Epoch 39/50
# 45000/45000 [==============================] - 13s 298us/step - loss: 0.0067 - accuracy: 0.9991 - val_loss: 0.0127 - val_accuracy: 0.9983
# Epoch 40/50
# 45000/45000 [==============================] - 13s 295us/step - loss: 0.0066 - accuracy: 0.9993 - val_loss: 0.0181 - val_accuracy: 0.9985
# Epoch 41/50
# 45000/45000 [==============================] - 13s 295us/step - loss: 0.0101 - accuracy: 0.9990 - val_loss: 0.0153 - val_accuracy: 0.9982
# Epoch 42/50
# 45000/45000 [==============================] - 13s 294us/step - loss: 0.0074 - accuracy: 0.9992 - val_loss: 0.0214 - val_accuracy: 0.9982
# Epoch 43/50
# 45000/45000 [==============================] - 13s 294us/step - loss: 0.0092 - accuracy: 0.9992 - val_loss: 0.0438 - val_accuracy: 0.9967
# Epoch 44/50
# 45000/45000 [==============================] - 13s 296us/step - loss: 0.0093 - accuracy: 0.9992 - val_loss: 0.0429 - val_accuracy: 0.9971
# Epoch 45/50
# 45000/45000 [==============================] - 13s 296us/step - loss: 0.0113 - accuracy: 0.9992 - val_loss: 0.0199 - val_accuracy: 0.9978
# Epoch 46/50
# 45000/45000 [==============================] - 13s 294us/step - loss: 0.0073 - accuracy: 0.9993 - val_loss: 0.0265 - val_accuracy: 0.9982
# Epoch 47/50
# 45000/45000 [==============================] - 13s 296us/step - loss: 0.0117 - accuracy: 0.9990 - val_loss: 0.0185 - val_accuracy: 0.9980
# Epoch 48/50
# 45000/45000 [==============================] - 13s 294us/step - loss: 0.0065 - accuracy: 0.9994 - val_loss: 0.0271 - val_accuracy: 0.9976
# Epoch 49/50
# 45000/45000 [==============================] - 13s 296us/step - loss: 0.0087 - accuracy: 0.9992 - val_loss: 0.0162 - val_accuracy: 0.9985
# Epoch 50/50
# 45000/45000 [==============================] - 13s 293us/step - loss: 0.0090 - accuracy: 0.9991 - val_loss: 0.0430 - val_accuracy: 0.9972
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# reshape_1 (Reshape)          (None, 28, 28, 1)         0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 28, 28, 64)        640
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 28, 28, 64)        36928
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 14, 14, 64)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 14, 14, 128)       73856
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 14, 14, 128)       147584
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 7, 7, 128)         0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 7, 7, 256)         295168
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 7, 7, 256)         590080
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 7, 7, 256)         590080
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 3, 3, 256)         0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 3, 3, 512)         1180160
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 3, 3, 512)         2359808
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 3, 3, 512)         2359808
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 1, 1, 512)         0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 1, 1, 512)         2359808
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 1, 1, 512)         2359808
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 1, 1, 512)         2359808
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               131328
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 10)                2570
# _________________________________________________________________
# activation_1 (Activation)    (None, 10)                0
# =================================================================
# Total params: 14,913,226
# Trainable params: 14,913,226
# Non-trainable params: 0
# _________________________________________________________________
# None
# CPU times: user 6min 28s, sys: 2min 14s, total: 8min 42s
# Wall time: 11min 4s

# %%
fig1 = plt.figure(figsize = (12,10))
ax1 = fig1.add_subplot(2,2,1)
ax2 = fig1.add_subplot(2,2,2)

ax1.plot(np.arange(1,nb_epoch+1), history.val_losses)
ax1.set(xlabel='Epochs', ylabel='Validation Loss',
       title='Epochs vs. Validation Loss')
ax2.plot(np.arange(1,nb_epoch+1), history.losses)
ax2.set(xlabel='Epochs', ylabel='Training Loss',
       title='Epochs vs. Training Loss')
plt.show()

# %%
fig1 = plt.figure(figsize = (12,10))
ax1 = fig1.add_subplot(2,2,1)
ax2 = fig1.add_subplot(2,2,2)

ax1.plot(np.arange(1,nb_epoch+1), history.val_acc)
ax1.set(xlabel='Epochs', ylabel='Validation Accuracy',
       title='Epochs vs. Validation Accuracy')
ax2.plot(np.arange(1,nb_epoch+1), history.acc)
ax2.set(xlabel='Epochs', ylabel='Training Accuracy',
       title='Epochs vs. Training Accuracy')
plt.show()

# %%
p = test_accuracy()
print("Test accuracy: {} %".format(p[1]))
# Out:
# Test accuracy: 98.92 %

# %%
fig1 = plt.figure(figsize = (15,15))

for i in range(5):
    ax1 = fig1.add_subplot(1,5,i+1) 
    ax1.imshow(x_test[p[2][i]], interpolation='none', cmap=plt.cm.gray)
    ax2 = fig1.add_subplot(2,5,i+6) 
    ax2.imshow(x_test[p[2][i+6]], interpolation='none', cmap=plt.cm.gray)
plt.show()

print("True:          {}".format(y_test[p[2][0:5]]))
print("classified as: {}".format(np.argmax(predictions[p[2][0:5]], axis=1)))

print("True:          {}".format(y_test[p[2][6:11]]))
print("classified as: {}".format(np.argmax(predictions[p[2][6:11]], axis=1)))
# Out:
# True:          [5 8 2 2 5]
# classified as: [6 4 7 1 3]
# True:          [3 3 2 6 2]
# classified as: [5 9 7 4 4]
